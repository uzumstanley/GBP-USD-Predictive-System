# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol and the date range for August 2019
ticker = "GBPUSD=X"
start_date = "2019-08-01"
end_date = "2019-08-31"

# Fetch the historical data for GBP/USD for August 2019
data = yf.download(ticker, start=start_date, end=end_date)

# Save the data to a CSV file
#data.to_csv("gbpusd_august_2019.csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2019-08-01  1.215466  1.215466  1.208196  1.215377   1.215377       0
# 2019-08-02  1.212724  1.214491  1.209175  1.212430   1.212430       0
# 2019-08-05  1.214919  1.218814  1.210317  1.215214   1.215214       0
# 2019-08-06  1.215613  1.220971  1.214285  1.215820   1.215820       0
# 2019-08-07  1.217226  1.219141  1.212224  1.216974   1.216974       0
# 2019-08-08  1.214167  1.218324  1.209775  1.214329   1.214329       0
# 2019-08-09  1.214477  1.214772  1.205734  1.214373   1.214373       0
# 2019-08-12  1.202198  1.210068  1.201923  1.202198   1.202198       0
# 2019-08-13  1.208021  1.209760  1.204355  1.207875   1.207875       0
# 2019-08-14  1.206418  1.209995  1.204674  1.206418   1.206418       0
# 2019-08-15  1.206040  1.214255  1.205110  1.206040   1.206040       0
# 2019-08-16  1.209219  1.217730  1.208313  1.209161   1.209161       0
# ...

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], marker='o', linestyle='-', color='b')
plt.title('GBP/USD Closing Prices - August 2019')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
